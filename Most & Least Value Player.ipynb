# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %% [markdown]
# ##  POTENTIAL SCORES CALC. USING ONLY EPL_PLAYERS DATASET

# %%
# Loading DataFrame
epl_players = pd.read_csv('epl_players.csv')

# %%
epl_players.columns
# Out:
# Index(['player_id', 'birthday', 'height', 'weight', 'date', 'preferred_foot',
#        'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes'],
#       dtype='object')

# %%
epl_players=epl_players.dropna()

# %%
#Creating a fitness parameter based on Height & wieght of the player
# Fitness = 100*(1 - (Weigth/Height))
epl_players['fitness'] = 100*(1 - (epl_players['weight']/epl_players['height']))

# %%
#Normalizing the fitness parameter

x = epl_players[['fitness']].values #returns a 2-D numpy array
min_max_scaler = preprocessing.MinMaxScaler()
fitness_scaled = min_max_scaler.fit_transform(x)
finess_normalized = pd.DataFrame(fitness_scaled)

# %%
# epl_players['Fitness'].max()
# print(finess_normalized)
epl_players['fitness_normalized'] = 100*finess_normalized
del epl_players['fitness']

# %%
#Creating a overall potential parameter based on all categorical data from 'crossing' to 'fitness_normalized'
col = epl_players.loc[: , 'crossing': 'fitness_normalized']
epl_players['Overall_potential'] = col.mean(axis=1)

# %%
#Final Dataset after considering EPL_PLAYERS DATASET
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  marking  \
# 0                high              medium      80.0       53.0  ...     76.0
# 1                high              medium      80.0       53.0  ...     76.0
# 2                high              medium      79.0       52.0  ...     76.0
# 3                high              medium      79.0       51.0  ...     76.0
# 4                high              medium      79.0       51.0  ...     76.0
#
#    standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0             75.0            78.0       14.0          7.0         9.0
# 1             75.0            78.0       14.0          7.0         9.0
# 2             75.0            78.0       14.0          7.0         9.0
# 3             75.0            78.0       14.0          7.0         9.0
# 4             75.0            78.0       14.0          7.0         9.0
#
#    gk_positioning  gk_reflexes  fitness_normalized  Overall_potential
# 0             9.0         12.0           71.604478          60.870720
# 1             9.0         12.0           71.604478          60.576602
# 2             9.0         12.0           71.604478          60.017779
# 3             9.0         12.0           71.604478          59.958955
# 4             9.0         12.0           71.604478          59.958955
#
# [5 rows x 43 columns]

# %% [markdown]
# ## EPL_GOALS DATASET

# %%
# Loading DataFrame
epl_goals = pd.read_csv('epl_goals.csv')

# %%
# epl_goals.head()
epl_goals.shape
# Out:
# (7561, 6)

# %%
epl_goals_1 = epl_goals.copy()

# %%
del epl_goals_1['match_id']
del epl_goals_1['player2_id']
del epl_goals_1['goal_type']
del epl_goals_1['team_id']
epl_goals_1.rename(columns = {'player1_id' : 'player_id'} , inplace = True)
epl_goals_1.head(20)
# Out:
#     goal_number  player_id
# 0             1    37799.0
# 1             2    24148.0
# 2             1    26181.0
# 3             1    30853.0
# 4             1    23139.0
# 5             2    23139.0
# 6             3   127857.0
# 7             1    26165.0
# 8             2    40198.0
# 9             3    23264.0
# 10            4    23264.0
# 11            5    23264.0
# 12            6    46403.0
# 13            1    30342.0
# 14            2    24011.0
# 15            3    24160.0
# 16            4    30646.0
# 17            5    37764.0
# 18            1    24166.0
# 19            2    24166.0

# %%
epl_goals_1=epl_goals_1.groupby(['player_id']).sum()

# %%
epl_goals_1.shape
# Out:
# (852, 1)

# %%
epl_goals_2 = epl_goals.copy()

# %%
del epl_goals_2['match_id']
del epl_goals_2['player1_id']
del epl_goals_2['goal_type']
del epl_goals_2['team_id']
epl_goals_2.rename(columns = {'player2_id' : 'player_id','goal_number':'goal_number2'} , inplace = True)
epl_goals_2.head()
# Out:
#    goal_number2  player_id
# 0             1    38807.0
# 1             2    24154.0
# 2             1    39297.0
# 3             1    30889.0
# 4             1    36394.0

# %%
#Considering player2 as half contributor in goal
epl_goals_2['goal_number2'] = epl_goals_2['goal_number2']/2
epl_goals_2.head()
# Out:
#    goal_number2  player_id
# 0           0.5    38807.0
# 1           1.0    24154.0
# 2           0.5    39297.0
# 3           0.5    30889.0
# 4           0.5    36394.0

# %%
epl_goals_2=epl_goals_2.groupby(['player_id']).sum()
epl_goals_2.shape
# Out:
# (831, 1)

# %%
epl_players=pd.merge(epl_players, epl_goals_1, on='player_id')

# %%
epl_players=pd.merge(epl_players, epl_goals_2, on='player_id')

# %%
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0            78.0       14.0          7.0         9.0             9.0
# 1            78.0       14.0          7.0         9.0             9.0
# 2            78.0       14.0          7.0         9.0             9.0
# 3            78.0       14.0          7.0         9.0             9.0
# 4            78.0       14.0          7.0         9.0             9.0
#
#    gk_reflexes  fitness_normalized  Overall_potential  goal_number  \
# 0         12.0           71.604478          60.870720            2
# 1         12.0           71.604478          60.576602            2
# 2         12.0           71.604478          60.017779            2
# 3         12.0           71.604478          59.958955            2
# 4         12.0           71.604478          59.958955            2
#
#    goal_number2
# 0           3.5
# 1           3.5
# 2           3.5
# 3           3.5
# 4           3.5
#
# [5 rows x 45 columns]

# %%
#Normalizing the goals parameter

x = epl_players[['goal_number']].values #returns a 2-D numpy array
min_max_scaler = preprocessing.MinMaxScaler()
goal_scaled = min_max_scaler.fit_transform(x)
goal_normalized = pd.DataFrame(goal_scaled)
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0            78.0       14.0          7.0         9.0             9.0
# 1            78.0       14.0          7.0         9.0             9.0
# 2            78.0       14.0          7.0         9.0             9.0
# 3            78.0       14.0          7.0         9.0             9.0
# 4            78.0       14.0          7.0         9.0             9.0
#
#    gk_reflexes  fitness_normalized  Overall_potential  goal_number  \
# 0         12.0           71.604478          60.870720            2
# 1         12.0           71.604478          60.576602            2
# 2         12.0           71.604478          60.017779            2
# 3         12.0           71.604478          59.958955            2
# 4         12.0           71.604478          59.958955            2
#
#    goal_number2
# 0           3.5
# 1           3.5
# 2           3.5
# 3           3.5
# 4           3.5
#
# [5 rows x 45 columns]

# %%
# Taking goals maximum 10 value for player value
epl_players['goal_normalized'] = 10*goal_normalized
del epl_players['goal_number']

# %%
#Normalizing the assisted goals parameter

x = epl_players[['goal_number2']].values #returns a 2-D numpy array
min_max_scaler = preprocessing.MinMaxScaler()
goal2_scaled = min_max_scaler.fit_transform(x)
goal2_normalized = pd.DataFrame(goal2_scaled)
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0            78.0       14.0          7.0         9.0             9.0
# 1            78.0       14.0          7.0         9.0             9.0
# 2            78.0       14.0          7.0         9.0             9.0
# 3            78.0       14.0          7.0         9.0             9.0
# 4            78.0       14.0          7.0         9.0             9.0
#
#    gk_reflexes  fitness_normalized  Overall_potential  goal_number2  \
# 0         12.0           71.604478          60.870720           3.5
# 1         12.0           71.604478          60.576602           3.5
# 2         12.0           71.604478          60.017779           3.5
# 3         12.0           71.604478          59.958955           3.5
# 4         12.0           71.604478          59.958955           3.5
#
#    goal_normalized
# 0          0.02849
# 1          0.02849
# 2          0.02849
# 3          0.02849
# 4          0.02849
#
# [5 rows x 45 columns]

# %%
# Taking goals maximum 5 value for player value
epl_players['assistance_normalized'] = 5*goal2_normalized
del epl_players['goal_number2']

# %%
#Final Dataset after considering EPL_GOALS DATASET
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0            78.0       14.0          7.0         9.0             9.0
# 1            78.0       14.0          7.0         9.0             9.0
# 2            78.0       14.0          7.0         9.0             9.0
# 3            78.0       14.0          7.0         9.0             9.0
# 4            78.0       14.0          7.0         9.0             9.0
#
#    gk_reflexes  fitness_normalized  Overall_potential  goal_normalized  \
# 0         12.0           71.604478          60.870720          0.02849
# 1         12.0           71.604478          60.576602          0.02849
# 2         12.0           71.604478          60.017779          0.02849
# 3         12.0           71.604478          59.958955          0.02849
# 4         12.0           71.604478          59.958955          0.02849
#
#    assistance_normalized
# 0                0.16129
# 1                0.16129
# 2                0.16129
# 3                0.16129
# 4                0.16129
#
# [5 rows x 45 columns]

# %% [markdown]
# ## EPL_POTENTIAL_SHOTS DATASET

# %%
epl_potential = pd.read_csv('epl_potential_shots.csv')
epl_potential.columns
# epl_potential.shape
# Out:
# Index(['match_id', 'team_id', 'shot_number', 'player1_id', 'shot_type'], dtype='object')

# %%
del epl_potential['match_id']
del epl_potential['shot_type']
del epl_potential['team_id']
epl_potential.rename(columns = {'player1_id' : 'player_id'} , inplace = True)

# %%
epl_potential=epl_potential.groupby(['player_id']).sum()
epl_potential.shape
# Out:
# (1126, 1)

# %%
epl_players=pd.merge(epl_players, epl_potential, on='player_id')

# %%
#Normalizing the potential_shots parameter

x = epl_players[['shot_number']].values #returns a 2-D numpy array
min_max_scaler = preprocessing.MinMaxScaler()
pot_scaled = min_max_scaler.fit_transform(x)
pot_normalized = pd.DataFrame(pot_scaled)
epl_players.head()
print(pot_normalized)
# Out:
#               0
# 0      0.053435
# 1      0.053435
# 2      0.053435
# 3      0.053435
# 4      0.053435
# ...         ...
# 17087  0.145370
# 17088  0.145370
# 17089  0.145370
# 17090  0.145370
# 17091  0.145370
#
# [17092 rows x 1 columns]

# %%
# Taking potential shots maximum 5 value for player value
epl_players['shot_normalized'] = 5*pot_normalized
del epl_players['shot_number']

# %%
#FINAL EPL_PLAYER DATASET AFTER CONSIDERING ALL RELEVANT ATTRIBUTES
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0       14.0          7.0         9.0             9.0         12.0
# 1       14.0          7.0         9.0             9.0         12.0
# 2       14.0          7.0         9.0             9.0         12.0
# 3       14.0          7.0         9.0             9.0         12.0
# 4       14.0          7.0         9.0             9.0         12.0
#
#    fitness_normalized  Overall_potential  goal_normalized  \
# 0           71.604478          60.870720          0.02849
# 1           71.604478          60.576602          0.02849
# 2           71.604478          60.017779          0.02849
# 3           71.604478          59.958955          0.02849
# 4           71.604478          59.958955          0.02849
#
#    assistance_normalized  shot_normalized
# 0                0.16129         0.267176
# 1                0.16129         0.267176
# 2                0.16129         0.267176
# 3                0.16129         0.267176
# 4                0.16129         0.267176
#
# [5 rows x 46 columns]

# %% [markdown]
# ## ADDING NEW COLUMN NAMED VALUE OF PLAYER

# %%
#Adding last 4 columns of dataframe to generate value of the player 
epl_players['Value_of_player'] =epl_players['Overall_potential'] +epl_players['goal_normalized'] + epl_players['assistance_normalized'] +epl_players['shot_normalized']

# %%
epl_players.head()
# Out:
#    player_id         birthday  height  weight             date preferred_foot  \
# 0     155782  12/15/1989 0:00  170.18   146.0   4/21/2016 0:00           left
# 1     155782  12/15/1989 0:00  170.18   146.0    4/7/2016 0:00           left
# 2     155782  12/15/1989 0:00  170.18   146.0    1/7/2016 0:00           left
# 3     155782  12/15/1989 0:00  170.18   146.0  12/24/2015 0:00           left
# 4     155782  12/15/1989 0:00  170.18   146.0  12/17/2015 0:00           left
#
#   attacking_work_rate defensive_work_rate  crossing  finishing  ...  \
# 0                high              medium      80.0       53.0  ...
# 1                high              medium      80.0       53.0  ...
# 2                high              medium      79.0       52.0  ...
# 3                high              medium      79.0       51.0  ...
# 4                high              medium      79.0       51.0  ...
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes  fitness_normalized  \
# 0          7.0         9.0             9.0         12.0           71.604478
# 1          7.0         9.0             9.0         12.0           71.604478
# 2          7.0         9.0             9.0         12.0           71.604478
# 3          7.0         9.0             9.0         12.0           71.604478
# 4          7.0         9.0             9.0         12.0           71.604478
#
#    Overall_potential  goal_normalized  assistance_normalized  shot_normalized  \
# 0          60.870720          0.02849                0.16129         0.267176
# 1          60.576602          0.02849                0.16129         0.267176
# 2          60.017779          0.02849                0.16129         0.267176
# 3          59.958955          0.02849                0.16129         0.267176
# 4          59.958955          0.02849                0.16129         0.267176
#
#    Value_of_player
# 0        61.327676
# 1        61.033558
# 2        60.474735
# 3        60.415911
# 4        60.415911
#
# [5 rows x 47 columns]

# %%
epl_players=epl_players.sort_values('Value_of_player')
epl_players.tail()
# Out:
#        player_id         birthday  height  weight            date  \
# 16591      30829  10/24/1985 0:00  175.26   183.0  2/22/2007 0:00
# 16589      30829  10/24/1985 0:00  175.26   183.0  8/30/2008 0:00
# 16590      30829  10/24/1985 0:00  175.26   183.0  8/30/2007 0:00
# 16588      30829  10/24/1985 0:00  175.26   183.0  8/30/2009 0:00
# 16587      30829  10/24/1985 0:00  175.26   183.0  2/22/2010 0:00
#
#       preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 16591          right                high                high      74.0
# 16589          right                high                high      76.0
# 16590          right                high                high      77.0
# 16588          right                high                high      81.0
# 16587          right                high                high      80.0
#
#        finishing  ...  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 16591       93.0  ...          7.0        71.0            11.0         12.0
# 16589       91.0  ...         21.0        75.0            21.0         21.0
# 16590       90.0  ...         21.0        72.0            21.0         21.0
# 16588       91.0  ...         21.0        80.0            21.0         21.0
# 16587       94.0  ...         21.0        86.0            21.0         21.0
#
#        fitness_normalized  Overall_potential  goal_normalized  \
# 16591           52.771739          70.552110          9.62963
# 16589           52.771739          70.846228          9.62963
# 16590           52.771739          71.787404          9.62963
# 16588           52.771739          71.787404          9.62963
# 16587           52.771739          73.199169          9.62963
#
#        assistance_normalized  shot_normalized  Value_of_player
# 16591               4.462366              5.0        89.644105
# 16589               4.462366              5.0        89.938223
# 16590               4.462366              5.0        90.879399
# 16588               4.462366              5.0        90.879399
# 16587               4.462366              5.0        92.291164
#
# [5 rows x 47 columns]

# %%
#removing duplicate plyer_id
epl_players=epl_players.drop_duplicates(subset = ['player_id'], keep='first')

# %% [markdown]
# # COPYING DESIRED OUTPUT TO SUBMISSION FILE

# %%
top = epl_players.nlargest(10, ['Value_of_player'])
top=top.filter(['player_id'])
top.rename(columns ={'player_id': 'most_valuable'} , inplace = True)
top = top.reset_index(drop  = True)

# %%
least=epl_players.nsmallest(10, ['Value_of_player'])
least = least.filter(['player_id'])
least.rename(columns ={'player_id': 'least_valuable'} , inplace = True)
least = least.reset_index(drop =True)

# %%
result = pd.concat([top, least], axis = 1 )
result
# Out:
#    most_valuable  least_valuable
# 0          30829          214426
# 1          30618           72417
# 2          30843           23794
# 3          37412          117545
# 4          30631           24952
# 5          36615           25156
# 6          30613           23686
# 7          38817          214570
# 8          38807          172841
# 9          37459           35523

# %%
#Copying to the destination file
result.to_csv('player_list_submission.csv',index=False)
